# %%
#importing libraries
from bs4 import BeautifulSoup
import requests
import time
import datetime
import pandas as pd
import csv
import smtplib

# %%
url1 = 'https://www.blackownedbrooklyn.com/stories/deptofculture'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36"}

page1 = requests.get(url1, headers = headers)
 
soup1= BeautifulSoup(page1.content, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(), 'html.parser')
soup2
# Out:
# <!DOCTYPE html>
#
# <html class="touch-styles" lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- This is Squarespace. -->
# <!-- rectangle-halibut-e72c -->
# <base href=""/>
# <meta charset="utf-8"/>
# <title>
#     Dept of Culture — Black-Owned Brooklyn
#    </title>
# <meta content="Sec-CH-UA-Platform-Version, Sec-CH-UA-Model" http-equiv="Accept-CH"/>
# <link href="https://images.squarespace-cdn.com/content/v1/5dcc78e38b58236558d18a10/1579727607404-8GFMJYCX3VL1TZXWZVWC/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://www.blackownedbrooklyn.com/stories/deptofculture" rel="canonical"/>
# <meta content="Black-Owned Brooklyn" property="og:site_name">
# <meta content="Dept of Culture — Black-Owned Brooklyn" property="og:title">
# ...

# %%
Business_name1 = soup2.find(class_="entry-title entry-title--large p-name").get_text()
em_tags1 = soup2.find_all('em')
address1 = em_tags1[-2]
website1 = em_tags1[-1]
print(Business_name1)
print(address1)
print(website1)
#else:
    #print('No <em> tags found')
#Business_name
#web_address
# Out:
#            Feb  1
#
#           Dept of Culture
#
# <em>
#                  327 Nostrand Ave., Brooklyn,
#                 </em>
# <em>
#                   deptofculturebk.com
#                  </em>

# %%
url2 = 'https://www.blackownedbrooklyn.com/stories/good-wine'

page2 = requests.get(url2, headers = headers)
 
soup3= BeautifulSoup(page2.content, "html.parser")
soup3
# Out:
# <!DOCTYPE html>
#
# <html class="touch-styles" lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- This is Squarespace. --><!-- rectangle-halibut-e72c -->
# <base href=""/>
# <meta charset="utf-8">
# <title>Good Wine — Black-Owned Brooklyn</title>
# <meta content="Sec-CH-UA-Platform-Version, Sec-CH-UA-Model" http-equiv="Accept-CH"><link href="https://images.squarespace-cdn.com/content/v1/5dcc78e38b58236558d18a10/1579727607404-8GFMJYCX3VL1TZXWZVWC/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://www.blackownedbrooklyn.com/stories/good-wine" rel="canonical"/>
# <meta content="Black-Owned Brooklyn" property="og:site_name"/>
# <meta content="Good Wine — Black-Owned Brooklyn" property="og:title"/>
# <meta content="40.7032302" property="og:latitude"/>
# ...

# %%
Business_name2 = soup3.find(class_="entry-title entry-title--large p-name").get_text()
em_tags2 = soup3.find_all('em')
address2 = em_tags2[-2]
website2 = em_tags2[-1]
print(Business_name2)
print(address2)
print(website2)
# Out:
# Jan 21 Good Wine
# <em>327 5th Ave, Brooklyn, 718-499-2392, </em>
# <em>goodwine.nyc</em>

# %%
url3 = 'https://www.blackownedbrooklyn.com/stories/brooklynsweetspot'

page3 = requests.get(url3, headers = headers)
 
soup4= BeautifulSoup(page3.content, "html.parser")

Business_name3 = soup4.find(class_="entry-title entry-title--large p-name").get_text()
em_tags3 = soup4.find_all('em')
#address3 = em_tags3[-2]
address3 = soup4.find(style="white-space:pre-wrap;").get_text()
website3 = em_tags3[-1]
print(Business_name3)
#print(address3)
print(website3)
# Out:
# Oct 29 Brooklyn Sweet Spot
# <em>thebrooklynsweetspot.com</em>

# %%
url4 = 'https://www.blackownedbrooklyn.com/stories/thenarativ'

page4 = requests.get(url4, headers = headers)
 
soup5= BeautifulSoup(page4.content, "html.parser")

Business_name4 = soup5.find(class_="entry-title entry-title--large p-name").get_text()
em_tags4 = soup5.find_all('em')
address4 = em_tags4[-3]
website4 = em_tags4[-1]
print(Business_name4)
print(address4)
print(website4)
# Out:
# Sep 30 The Narativ House x Brooklyn Kettle
# <em>thenarativ.com</em>
# <em>brooklynkettle.com</em>

# %%
url5 = 'https://www.blackownedbrooklyn.com/stories/thenarativ'

page5 = requests.get(url5, headers = headers)
 
soup6 = BeautifulSoup(page5.content, "html.parser")

Business_name5 = soup6.find(class_="entry-title entry-title--large p-name").get_text()
em_tags5 = soup5.find_all('em')
address5 = em_tags5[-3]
website5 = em_tags5[-1]
print(Business_name5)
print(address5)
print(website5)
# Out:
# Sep 30 The Narativ House x Brooklyn Kettle
# <em>thenarativ.com</em>
# <em>brooklynkettle.com</em>

# %%
url6 = 'https://www.blackownedbrooklyn.com/stories/kelewele'

page6 = requests.get(url6, headers = headers)
 
soup7 = BeautifulSoup(page6.content, "html.parser")

Business_name6 = soup7.find(class_="entry-title entry-title--large p-name").get_text()
em_tags6 = soup7.find_all('em')
address6 = em_tags6[-2]
website6 = em_tags6[-1]
print(Business_name6)
print(address6)
print(website6)
# Out:
# Aug 27 Kelewele
# <em>Dekalb Market Hall, 445 Albee Square W,, 929-322-3480, </em>
# <em>kelewelenyc.com</em>

# %%
url7 = 'https://www.blackownedbrooklyn.com/stories/bierwax'

page7 = requests.get(url7, headers = headers)
 
soup8 = BeautifulSoup(page7.content, "html.parser")

Business_name7 = soup8.find(class_="entry-title entry-title--large p-name").get_text()
em_tags7 = soup8.find_all('em')
address7 = em_tags7[-2]
address_tag = soup8.find('p', class_="").get_text() # find the <p> tag with class=""
#addresss = address_tag.get_text()
#website7 = em_tags7[-1]
#print(Business_name7)
#print(address7)
#print(website7)
#print(addresss)
address_tag
# Out:
# ' '

# %%
url8 = 'https://www.blackownedbrooklyn.com/stories/zanmi'

page8 = requests.get(url8, headers = headers)
 
soup9 = BeautifulSoup(page8.content, "html.parser")

Business_name8 = soup9.find(class_="entry-title entry-title--large p-name").get_text()
em_tags8 = soup9.find_all('em')
address8 = em_tags8[-2]
website8 = em_tags8[-1]
print(Business_name8)
print(address8)
print(website8)
# Out:
# Aug 13 Zanmi
# <em>1206 Nostrand Ave., 718-676-1047, </em>
# <em>zanminyc.com</em>

# %%
url9 = 'https://www.blackownedbrooklyn.com/stories/mothershuckers'

page9 = requests.get(url9, headers = headers)
 
soup10 = BeautifulSoup(page9.content, "html.parser")

Business_name9 = soup10.find(class_="entry-title entry-title--large p-name").get_text()
em_tags9 = soup10.find_all('em')
address9 = em_tags9[-2]#no address
website9 = em_tags9[-1]
print(Business_name9)
print(address9)
print(website9)
# Out:
# Jul 30 The Real Mother Shuckers
# <em>am</em>
# <em>therealmothershuckersnyc.com</em>

# %%
url10 = 'https://www.blackownedbrooklyn.com/stories/macshack'

page10 = requests.get(url10, headers = headers)
 
soup11 = BeautifulSoup(page10.content, "html.parser")

Business_name10 = soup11.find(class_="entry-title entry-title--large p-name").get_text()
em_tags10 = soup11.find_all('em')
address10 = em_tags10[-2]
website10 = em_tags10[-1]
print(Business_name10)
print(address10)
print(website10)
# Out:
# Aug 20 Mac Shack
# <em>320 Malcolm X Blvd., 718-210-9603, </em>
# <em>macshacknyc.com</em>

# %%
url11 = 'https://www.blackownedbrooklyn.com/stories/lipscafe'

page11 = requests.get(url11, headers = headers)
 
soup12 = BeautifulSoup(page11.content, "html.parser")

Business_name11 = soup12.find(class_="entry-title entry-title--large p-name").get_text()
em_tags11 = soup12.find_all('em')
address11 = em_tags11[-3]
website11 = em_tags11[-1]
print(Business_name11)
print(address11)
print(website11)
# Out:
# Jun  3 Lips Cafe
# <em>1412 Nostrand Ave, Brooklyn, 347-240-4439,</em>
# <em>Lips Cafe</em>

# %%
url12 = 'https://www.blackownedbrooklyn.com/stories/lotusscoop'

page12 = requests.get(url12, headers = headers)
 
soup13 = BeautifulSoup(page12.content, "html.parser")

Business_name12 = soup13.find(class_="entry-title entry-title--large p-name").get_text()
em_tags12 = soup13.find_all('em')
# = em_tags12[-3]#no address
website_tag = soup13.find('a', href=True, text='LotusScoop.com')
website12 = website_tag['href']
#website12 = website_tag['href']
print(Business_name12)
#print(address12)
print(website12)
# Out:
# Apr  7 Lotus Scoop
# https://lotusscoop.com/

# %%
url13 = 'https://www.blackownedbrooklyn.com/stories/paperboyloveprince'

page13 = requests.get(url13, headers = headers)
 
soup14 = BeautifulSoup(page13.content, "html.parser")

Business_name13 = soup14.find(class_="entry-title entry-title--large p-name").get_text()
em_tags13 = soup14.find_all('em')
#address13 = em_tags13[-2]
address13 = em_tags13[-1]
website_tag = soup14.find('a', href=True, text='paperboyprince.com')
website13 = website_tag['href']
print(Business_name13)
print(address13)
print(website13)
# Out:
# Jun 30 Paperboy Love Prince
# <em>1254 Myrtle Avenue., Brooklyn, </em>
# https://linktr.ee/PaperboyPrince

# %%
url13 = 'https://www.blackownedbrooklyn.com/stories/paperboyloveprince'

page13 = requests.get(url13, headers = headers)
 
soup14 = BeautifulSoup(page13.content, "html.parser")

Business_name13 = soup14.find(class_="entry-title entry-title--large p-name").get_text()
em_tags13 = soup14.find_all('em')
#address13 = em_tags13[-2]
address13 = em_tags13[-1]
website_tag = soup14.find('a', href=True, text='paperboyprince.com')
website13 = website_tag['href']
print(Business_name13)
print(address13)
print(website13)
# Out:
# Jun 30 Paperboy Love Prince
# <em>1254 Myrtle Avenue., Brooklyn, </em>
# https://linktr.ee/PaperboyPrince

# %%
url14 = 'https://www.blackownedbrooklyn.com/stories/cheris'

page14 = requests.get(url14, headers = headers)
 
soup15 = BeautifulSoup(page14.content, "html.parser")

Business_name14 = soup15.find(class_="entry-title entry-title--large p-name").get_text()
em_tags14 = soup15.find_all('em')
#address13 = em_tags13[-2]
address14 = em_tags14[-1]
#website_tag = soup15.find('a', href=True, text='paperboyprince.com')
#website14 = website_tag['href']
print(Business_name14)
print(address14)
#print(website14) #no website just insta
# Out:
# Apr  6 Cheri's Bed-Stuy
# <em>216 Malcolm X Blvd, 718-576-6655, </em>

# %%
url15 = 'https://www.blackownedbrooklyn.com/stories/paperboyloveprince'

page15 = requests.get(url15, headers = headers)
 
soup16 = BeautifulSoup(page15.content, "html.parser")

Business_name15 = soup16.find(class_="entry-title entry-title--large p-name").get_text()
em_tags15 = soup16.find_all('em')
#website15 = em_tags13[-2]
address15 = em_tags13[-1]
#website_tag = soup14.find('a', href=True, text='auntsetuncles.com')
#website15 = website_tag['href']
print(Business_name15)
print(address15)
#print(website15)
# Out:
# Jun 30 Paperboy Love Prince
# <em>1254 Myrtle Avenue., Brooklyn, </em>

# %%
url16 = 'https://www.blackownedbrooklyn.com/stories/brooklynsuya'

page16 = requests.get(url16, headers = headers)
 
soup17 = BeautifulSoup(page16.content, "html.parser")

Business_name16 = soup17.find(class_="entry-title entry-title--large p-name").get_text()
em_tags16 = soup17.find_all('em')
website16 = em_tags16[-1]
phone16 = em_tags16[-2]
address16 = em_tags16[-3]
#website_tag = soup17.find('a', href=True, text='paperboyprince.com')
#website16 = website_tag['href']
print(Business_name16)
print(address16)
print(website16)
print(phone16)
# Out:
# Feb 25 Brooklyn Suya
# <em>717 Franklin Ave, Brooklyn</em>
# <em>brooklynsuya.com</em>
# <em> 718-513-0122, </em>

# %%
url17 = 'https://www.blackownedbrooklyn.com/stories/bakeryonbergen'

page17 = requests.get(url17, headers = headers)
 
soup18 = BeautifulSoup(page17.content, "html.parser")

Business_name17 = soup18.find(class_="entry-title entry-title--large p-name").get_text()
em_tags17 = soup18.find_all('em')
phone17 = em_tags17[-1]
address17 = em_tags17[-2]
#website_tag = soup17.find('a', href=True, text='bakeryonbergen.com')
#website17 = website_tag['href']
print(Business_name17)
print(address17)
#print(website17) #website is printing an error
print(phone17)
# Out:
# Dec 21 The Bakery on Bergen
# <em>740 Bergen St</em>
# <em> Brooklyn, 917-519-6549, </em>

# %%
url18 = 'https://www.blackownedbrooklyn.com/stories/likkle'

page18 = requests.get(url18, headers = headers)
 
soup19 = BeautifulSoup(page18.content, "html.parser")

Business_name18 = soup19.find(class_="entry-title entry-title--large p-name").get_text()
em_tags18 = soup19.find_all('em')
website18 = em_tags18[-2]
address18 = em_tags18[-1]
print(Business_name18)
print(address18)
print(website18)
# Out:
# Nov 15 Likkle Jamaican Dumpling House
# <em>likkle.nyc</em>
# <em>884 Fulton St, Brooklyn, 347-463-9750, </em>

# %%
url19 = 'https://www.blackownedbrooklyn.com/stories/joloff'

page19 = requests.get(url19, headers = headers)
 
soup20 = BeautifulSoup(page19.content, "html.parser")

Business_name19 = soup20.find(class_="entry-title entry-title--large p-name").get_text()
em_tags19 = soup20.find_all('em')
website19 = em_tags19[-2]
address19 = em_tags19[-1]
#website_tag = soup14.find('a', href=True, text='auntsetuncles.com')
#website15 = website_tag['href']
print(Business_name19)
print(address19)
print(website19)
# Out:
# Oct 28 Joloff
# <em>joloffjoloff.com</em>
# <em>1168 Bedford Ave, Brooklyn, 718-230-0523, </em>

# %%
url20 = 'https://www.blackownedbrooklyn.com/stories/therogersgarden'

page20 = requests.get(url20, headers = headers)
 
soup21 = BeautifulSoup(page20.content, "html.parser")

Business_name20 = soup21.find(class_="entry-title entry-title--large p-name").get_text()
em_tags20 = soup21.find_all('em')
#website20 = em_tags20[-2]
address20 = em_tags20[-1]
website_tag = soup21.find('a', href=True, text='therogersgarden.com')
website20 = website_tag['href']
print(Business_name20)
print(address20)
print(website20)
# Out:
# Oct  1 The Rogers Garden
# <em>708 Rogers Ave, Brooklyn, 347-295-3866, </em>
# https://www.therogersgarden.com/

# %%
url21 = 'https://www.blackownedbrooklyn.com/stories/badnboozy'

page21 = requests.get(url21, headers = headers)
 
soup22 = BeautifulSoup(page21.content, "html.parser")

Business_name21 = soup22.find(class_="entry-title entry-title--large p-name").get_text()
em_tags21 = soup22.find_all('em')
#website21 = em_tags21[-2]
#address21 = em_tags21[-1]
website_tag = soup22.find('a', href=True, text='badxboozy.com')
website21 = website_tag['href']
print(Business_name21)
#print(address21) No address
print(website21)
# Out:
# Aug 14 Bad & Boozy
# https://www.badxboozy.com/

# %%
url22 = 'https://www.blackownedbrooklyn.com/stories/brooklyn-supported-agriculture'

page22 = requests.get(url22, headers = headers)
 
soup23 = BeautifulSoup(page22.content, "html.parser")

Business_name22 = soup23.find(class_="entry-title entry-title--large p-name").get_text()
em_tags22 = soup23.find_all('em')
#website21 = em_tags21[-2]
#address21 = em_tags21[-1]
#website_tag = soup23.find('a', href=True, text='badxboozy.com')
#website22 = website_tag['href']
print(Business_name22)
#print(address22) No address
#print(website22) # come back to check website error
# Out:
# Aug  8 Brooklyn Supported Agriculture

# %%
url23 = 'https://www.blackownedbrooklyn.com/stories/cuts-and-slices'

page23 = requests.get(url23, headers = headers)
 
soup24 = BeautifulSoup(page23.content, "html.parser")

Business_name23 = soup24.find(class_="entry-title entry-title--large p-name").get_text()
em_tags23 = soup24.find_all('em')
address23= em_tags23[-1]
#address23 = em_tags23[-2]
#website_tag = soup24.find('a', href=True, text='<a href="Slices on Instagram')
#website23 = website_tag['href']
print(Business_name23)
print(address23)#it printed address and phone
#print(website23) #website is printing an error
#print(phone23) #it printed address and phone
# Out:
# Jul 29 Cuts & Slices
# <em>93 Howard Ave, 718-552-2652, </em>

# %%
url24 = 'https://www.blackownedbrooklyn.com/stories/milk-and-pull'

page24 = requests.get(url24, headers = headers)
 
soup25 = BeautifulSoup(page24.content, "html.parser")

Business_name24 = soup25.find(class_="entry-title entry-title--large p-name").get_text()
em_tags24 = soup25.find_all('em')
phone24 = em_tags24[-1]
address24 = em_tags24[-2]
#website_tag = soup17.find('a', href=True, text='bakeryonbergen.com')
#website17 = website_tag['href']
print(Business_name24)
print(address24)
#print(website17) #website is printing an error
print(phone24)
# Out:
# Jul  8 Milk & Pull
# <em>307 Malcolm X Blvd, Brooklyn, 347-533-8967, </em>
# <em>milkandpull.com</em>

# %%
url25 = 'https://www.blackownedbrooklyn.com/stories/bednos-liquidassets'

page25 = requests.get(url25, headers = headers)
 
soup26 = BeautifulSoup(page25.content, "html.parser")

Business_name25 = soup26.find(class_="entry-title entry-title--large p-name").get_text()
em_tags25 = soup26.find_all('em')
phone25 = em_tags25[-1]
address25 = em_tags25[-2]
#website_tag = soup17.find('a', href=True, text='bakeryonbergen.com')
#website17 = website_tag['href']
print(Business_name25)
print(address25)
#print(website17) #website is printing an error
print(phone25)
# Out:
# Jul 15 Bedford Nostrand Wine + Liquid Assets
# <em>504 Nostrand Ave, Brooklyn, 718-676-0757, </em>
# <em>liquidassetsbk.com</em>

# %%
url25 = 'https://www.blackownedbrooklyn.com/stories/bednos-liquidassets'

page25 = requests.get(url25, headers = headers)
 
soup26 = BeautifulSoup(page25.content, "html.parser")

Business_name25b = soup26.find(class_="entry-title entry-title--large p-name").get_text()
em_tags25 = soup26.find_all('em')
phone25b = em_tags25[-3]
address25b = em_tags25[-4]
#website_tag = soup17.find('a', href=True, text='bakeryonbergen.com')
#website17 = website_tag['href']
print(Business_name25b)
print(address25b)
#print(website17) #website is printing an error
print(phone25b)
# Out:
# Jul 15 Bedford Nostrand Wine + Liquid Assets
# <em>296 Nostrand Ave, Brooklyn, 718-789-9463, </em>
# <em>bednos.com</em>

# %%
url26 = 'https://www.blackownedbrooklyn.com/stories/buy-better-foods'

page26 = requests.get(url26, headers = headers)
 
soup27 = BeautifulSoup(page26.content, "html.parser")

Business_name26 = soup27.find(class_="entry-title entry-title--large p-name").get_text()
em_tags26 = soup27.find_all('em')
address26 = em_tags26[-1]
#website_tag = soup27.find('a', href=True, text='<a href="buybetterfoods.com')
#website26 = website_tag['href']
print(Business_name26)
print(address26)
#print(website17) #website is printing an error
# Out:
# Jul  2 Buy Better Foods
# <em>372 Kosciuszko St, Brooklyn, 347-365-9550, </em>

# %%
url27 = 'https://www.blackownedbrooklyn.com/stories/shaquanda-will-feed-you'

page27 = requests.get(url27, headers = headers)
 
soup28 = BeautifulSoup(page27.content, "html.parser")

Business_name27 = soup28.find(class_="entry-title entry-title--large p-name").get_text()
em_tags27 = soup28.find_all('em')
#address27 = em_tags27[-1]
#website27 = em_tags27[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name27)
#print(address27)# No address
#print(website27) #website is printing an error
# Out:
# Jun 26 Shaquanda's Hot Pepper Sauce

# %%
url28 = 'https://www.blackownedbrooklyn.com/stories/ras-plant-based'

page28 = requests.get(url28, headers = headers)
 
soup29 = BeautifulSoup(page28.content, "html.parser")

Business_name28 = soup29.find(class_="entry-title entry-title--large p-name").get_text()
em_tags28 = soup29.find_all('em')
website28 = em_tags28[-1]
address28=  em_tags28[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name28)
print(address28)# No address
print(website28) #website is printing an error
# Out:
# Jun  3 Ras Plant Based
# <em>739 Franklin Ave, Brooklyn, 718-622-6220, </em>
# <em>rasplantbased.com</em>

# %%
url29 = 'https://www.blackownedbrooklyn.com/stories/brown-butter'

page29 = requests.get(url29, headers = headers)
 
soup30 = BeautifulSoup(page29.content, "html.parser")

Business_name29 = soup30.find(class_="entry-title entry-title--large p-name").get_text()
em_tags29 = soup30.find_all('em')
website29 = em_tags29[-1]
address29 =  em_tags29[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name29)
print(address29)# No address
print(website29) #website is printing an error
# Out:
# Jun 18 Brown Butter Craft Bar & Kitchen
# <em>413 Tompkins Ave, Brooklyn, 347-683-2116, </em>
# <em>brownbutternyc.com</em>

# %%
url30 = 'https://www.blackownedbrooklyn.com/stories/cafe-on-ralph'

page30 = requests.get(url30, headers = headers)
 
soup31 = BeautifulSoup(page30.content, "html.parser")

Business_name30 = soup31.find(class_="entry-title entry-title--large p-name").get_text()
em_tags30 = soup31.find_all('em')
website30 = em_tags30[-1]
address30 =  em_tags30[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name30)
print(address30)# No address  #this cafe is closed
print(website30) #website is printing an error
# Out:
# May  6 Cafe On Ralph (Closed)
# <em>86 Ralph Ave, Brooklyn, 347-413-5753, </em>
# <em>cafeonralphavenue.com</em>

# %%
url31 = 'https://www.blackownedbrooklyn.com/stories/the-bergen'

page31 = requests.get(url31, headers = headers)
 
soup32 = BeautifulSoup(page31.content, "html.parser")

Business_name31 = soup32.find(class_="entry-title entry-title--large p-name").get_text()
em_tags31 = soup32.find_all('em')
website31 = em_tags31[-1]
address31 =  em_tags31[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name31)
print(address31)
print(website31)
# Out:
# May 20 The Bergen
# <em>1299 Bergen Street, 347-240-7046, </em>
# <em>theberbgenbk.com</em>

# %%
url32 = 'https://www.blackownedbrooklyn.com/stories/black-nile'

page32 = requests.get(url32, headers = headers)
 
soup33 = BeautifulSoup(page32.content, "html.parser")

Business_name32 = soup33.find(class_="entry-title entry-title--large p-name").get_text()
em_tags32 = soup33.find_all('em')
website32 = em_tags32[-1]
address32 =  em_tags32[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name32)
print(address32)# No address  #this cafe is closed
print(website32) #website is printing an error
# Out:
# Apr  9 Black Nile
# <em>592 Nostrand Ave, Brooklyn, 347-879-8911, </em>
# <em>blacknilerestaurant.com</em>

# %%
url33 = 'https://www.blackownedbrooklyn.com/stories/bk9'

page33 = requests.get(url33, headers = headers)
 
soup34 = BeautifulSoup(page33.content, "html.parser")

Business_name33 = soup34.find(class_="entry-title entry-title--large p-name").get_text()
em_tags33 = soup34.find_all('em')
website33 = em_tags33[-1]
address33 =  em_tags33[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name33)
print(address33)
print(website33)
# Out:
# Apr 29 BK9
# <em>62 5th Ave, Brooklyn, 718-789-2176, </em>
# <em>bk9.nyc</em>

# %%
url34 = 'https://www.blackownedbrooklyn.com/stories/nurish'

page34 = requests.get(url34, headers = headers)
 
soup35 = BeautifulSoup(page34.content, "html.parser")

Business_name34 = soup35.find(class_="entry-title entry-title--large p-name").get_text()
em_tags34 = soup35.find_all('em')
website34 = em_tags34[-1]
address34 =  em_tags34[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name34)
print(address34)
print(website34)
# Out:
# Apr  2 Nûrish
# <em>637 Washington Ave, Brooklyn, 718-484-1122, </em>
# <em>nurishbk.com</em>

# %%
url35 = 'https://www.blackownedbrooklyn.com/stories/italkitchen'

page35 = requests.get(url35, headers = headers)
 
soup36 = BeautifulSoup(page35.content, "html.parser")

Business_name35 = soup36.find(class_="entry-title entry-title--large p-name").get_text()
em_tags35 = soup36.find_all('em')
website35 = em_tags35[-1]
address35 =  em_tags35[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name35)
print(address35)
print(website35)
# Out:
# Feb 20 Ital Kitchen
# <em>1032 Union Street, 347-405-9727, </em>
# <em>www.italkitchenbk.com</em>

# %%
url36 = 'https://www.blackownedbrooklyn.com/stories/happy-cork'

page36 = requests.get(url36, headers = headers)
 
soup37 = BeautifulSoup(page36.content, "html.parser")

Business_name36 = soup37.find(class_="entry-title entry-title--large p-name").get_text()
em_tags36 = soup37.find_all('em')
website36 = em_tags36[-1]
address36 =  em_tags36[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name36)
print(address36)
print(website36)
# Out:
# Mar 19 Happy Cork
# <em>51 Buffalo Ave, Brooklyn, 347-985-9067, </em>
# <em>happy-cork.com</em>

# %%
url37 = 'https://www.blackownedbrooklyn.com/stories/zaca-cafe'

page37 = requests.get(url37, headers = headers)
 
soup38 = BeautifulSoup(page37.content, "html.parser")

Business_name37 = soup38.find(class_="entry-title entry-title--large p-name").get_text()
em_tags37 = soup38.find_all('em')
website37 = em_tags37[-1]
address37 =  em_tags37[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name37)
print(address37)
print(website37)
# Out:
# Jan 21 Zaca Cafe
# <em>426  Marcus Garvey Blvd., 718- 443-2500, </em>
# <em>www.zacacafe.com </em>

# %%
url38 = 'https://www.blackownedbrooklyn.com/stories/bcakeny'

page38 = requests.get(url38, headers = headers)
 
soup39 = BeautifulSoup(page38.content, "html.parser")

Business_name38 = soup39.find(class_="entry-title entry-title--large p-name").get_text()
em_tags38 = soup39.find_all('em')
website38 = em_tags38[-1]
address38 =  em_tags38[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name38)
print(address38)
print(website38)
# Out:
# Mar 24 BCakeNY
# <em>702 Washington Ave, Brooklyn, 347-787-7199, </em>
# <em>bcakeny.com</em>

# %%
url39 = 'https://www.blackownedbrooklyn.com/stories/daleview-biscuits-and-beer'

page39 = requests.get(url39, headers = headers)
 
soup40 = BeautifulSoup(page39.content, "html.parser")

Business_name39 = soup40.find(class_="entry-title entry-title--large p-name").get_text()
em_tags39 = soup40.find_all('em')
website39 = em_tags39[-1]
address39 =  em_tags39[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name39)
print(address39)
print(website39)
# Out:
# Sep 20 Daleview Biscuits and Beer
# <em>1170 Nostrand Avenue, 347-240-5110, </em>
# <em>biscuitsandbeer.nyc</em>

# %%
url40 = 'https://www.blackownedbrooklyn.com/stories/buntons-world-famous'

page40 = requests.get(url40, headers = headers)
 
soup41 = BeautifulSoup(page40.content, "html.parser")

Business_name40 = soup41.find(class_="entry-title entry-title--large p-name").get_text()
em_tags40 = soup41.find_all('em')
#website40 = em_tags40[-1]
#address40 =  em_tags40[-2]
#website_tag = soup41.find('a', href=True, text='<a href=">buntonsworldfamous.com')
#website40 = website_tag['href'] 
print(Business_name40)
#print(address40) look for how to print address
#print(website40) website is priniting error
# Out:
# Nov 14 Bunton's World Famous

# %%
url41 = 'https://www.blackownedbrooklyn.com/stories/brooklyn-brewed-sorrel'

page41 = requests.get(url41, headers = headers)
 
soup42 = BeautifulSoup(page41.content, "html.parser")

Business_name41 = soup42.find(class_="entry-title entry-title--large p-name").get_text()
em_tags41 = soup42.find_all('em')
website41 = em_tags41[-1]
#address41 =  em_tags41[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name41)
#print(address41) has no address
print(website41)
# Out:
# Sep  6 Brooklyn Brewed Sorrel
# <em>brooklynbrewedsorrel.com</em>

# %%
url42 = 'https://www.blackownedbrooklyn.com/stories/branch-patty'

page42 = requests.get(url42, headers = headers)
 
soup43 = BeautifulSoup(page42.content, "html.parser")

Business_name42 = soup43.find(class_="entry-title entry-title--large p-name").get_text()
em_tags42 = soup43.find_all('em')
website42 = em_tags42[-1]
#address42 =  soup43.find("div", class_="sqs-block-content").get_text()3#
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name42)
#print(address42) come back to this 
print(website42)
# Out:
# Aug 16 Branch Patty
# <em>www.branchpatty.com</em>

# %%
url42 = 'https://www.blackownedbrooklyn.com/stories/bed-vyne-wine-spirits'

page42 = requests.get(url42, headers = headers)
 
soup43 = BeautifulSoup(page42.content, "html.parser")

Business_name42 = soup43.find(class_="entry-title entry-title--large p-name").get_text()
em_tags42 = soup43.find_all('em')
website42 = em_tags42[-1]
address42 =  em_tags41[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name42)
print(address42) #address issue
print(website42)
# Out:
# Apr 28 Bed-Vyne Wine & Spirits
# <em>and</em>
# <em>wine.bed-vyne.com</em>

# %%
url43 = 'https://www.blackownedbrooklyn.com/stories/biyou'

page43 = requests.get(url43, headers = headers)
 
soup44 = BeautifulSoup(page43.content, "html.parser")

Business_name43 = soup44.find(class_="entry-title entry-title--large p-name").get_text()
em_tags43 = soup44.find_all('em')
website43 = em_tags43[-1]
address43 =  em_tags43[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name43)
print(address43) #address issue
print(website43)
# Out:
# May  2 Biyou
# <em>198 Lewis Avenue, 718-928-7555, </em>
# <em>biyoubk.com</em>

# %%
url44 = 'https://www.blackownedbrooklyn.com/stories/rain-eatery-juice-bar'

page44 = requests.get(url44, headers = headers)
 
soup45 = BeautifulSoup(page44.content, "html.parser")

Business_name44 = soup45.find(class_="entry-title entry-title--large p-name").get_text()
em_tags44 = soup45.find_all('em')
#website44 = em_tags44[-1]
address44 =  em_tags44[-2]
website_tag = soup45.find('a', href=True, text='Rain Eatery on Instagram')
website44 = website_tag['href']
print(Business_name44)
print(address44) #address issue
print(website44)
# Out:
# Mar 25 Rain Eatery & Juice Bar
# <em>1166 Nostrand Avenue, 718-484-1443, </em>
# https://www.instagram.com/raineatery/

# %%
url45 = 'https://www.blackownedbrooklyn.com/stories/brooklyn-tea'

page45 = requests.get(url45, headers = headers)
 
soup46 = BeautifulSoup(page45.content, "html.parser")

Business_name45 = soup46.find(class_="entry-title entry-title--large p-name").get_text()
em_tags45 = soup46.find_all('em')
website45 = em_tags45[-1]
#address45 =  em_tags45[-2]
#website_tag = soup45.find('a', href=True, text='Rain Eatery on Instagram')
#website44 = website_tag['href']
print(Business_name45)
#print(address45) 
print(website45) #prints website and address
# Out:
# Apr  2 Brooklyn Tea
# <em>524 Nostrand Avenue, 347-240-4281, brooklyntea.com</em>

# %%
url46 = 'https://www.blackownedbrooklyn.com/stories/akwaaba-mansion'

page46 = requests.get(url46, headers = headers)
 
soup47 = BeautifulSoup(page46.content, "html.parser")

Business_name46 = soup47.find(class_="entry-title entry-title--large p-name").get_text()
em_tags46 = soup47.find_all('em')
website46 = em_tags46[-1]
address46 =  em_tags46[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name46)
print(address46) #address issue
print(website46)

# %%
url47 = 'https://www.blackownedbrooklyn.com/stories/lakou-cafe'

page47 = requests.get(url47, headers = headers)
 
soup48 = BeautifulSoup(page47.content, "html.parser")

Business_name47 = soup48.find(class_="entry-title entry-title--large p-name").get_text()
em_tags47 = soup48.find_all('em')
address47 = em_tags47[-1]
website47 =  em_tags47[-2]
#website_tag = soup46.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website45 = website_tag['href']
print(Business_name47)
print(address47) #address issue
print(website47)

# %%
url48 = 'https://www.blackownedbrooklyn.com/stories/bushwick-grind'

page48 = requests.get(url48, headers = headers)
 
soup49 = BeautifulSoup(page48.content, "html.parser")

Business_name48 = soup49.find(class_="entry-title entry-title--large p-name").get_text()
em_tags48 = soup47.find_all('em')
website48 = em_tags48[-1]
address48 =  em_tags48[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name48)
print(address48) #address issue
print(website48)

# %%
url49 = 'https://www.blackownedbrooklyn.com/stories/sofia-and-grace-cookie-company'

page49 = requests.get(url49, headers = headers)
 
soup50 = BeautifulSoup(page49.content, "html.parser")

Business_name49 = soup50.find(class_="entry-title entry-title--large p-name").get_text()
em_tags49 = soup50.find_all('em')
website49 = em_tags49[-1]
address49 =  em_tags49[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name49)
print(address49) #address issue
print(website49)

# %%
url50 = 'https://www.blackownedbrooklyn.com/stories/baby-jane'

page50 = requests.get(url50, headers = headers)
 
soup50 = BeautifulSoup(page50.content, "html.parser")

Business_name50 = soup51.find(class_="entry-title entry-title--large p-name").get_text()
em_tags50= soup51.find_all('em')
website50 = em_tags50[-1]
address50 =  em_tags50[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name50)
print(address50) #address issue
print(website50)

# %%
url51 = 'https://www.blackownedbrooklyn.com/stories/bati-ethiopian-kitchen'

page51 = requests.get(url51, headers = headers)
 
soup52 = BeautifulSoup(page51.content, "html.parser")

Business_name51 = soup52.find(class_="entry-title entry-title--large p-name").get_text()
em_tags51 = soup52.find_all('em')
website51 = em_tags51[-1]
address51 =  em_tags51[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name51)
print(address51) #address issue
print(website51)

# %%
url52 = 'https://www.blackownedbrooklyn.com/stories/cheryls-global-soul'

page52 = requests.get(url52, headers = headers)
 
soup53 = BeautifulSoup(page52.content, "html.parser")

Business_name52 = soup53.find(class_="entry-title entry-title--large p-name").get_text()
em_tags52 = soup53.find_all('em')
website52 = em_tags52[-1]
address52 =  em_tags52[-2]
#website_tag = soup28.find('a', href=True, text='<a href="shaquandawillfeedyou.com')
#website27 = website_tag['href']
print(Business_name52)
print(address52) #address issue
print(website52)
