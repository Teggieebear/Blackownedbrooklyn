# %%
#Import libraries
import requests
from bs4 import BeautifulSoup

# %%
urls = [
    'https://www.blackownedbrooklyn.com/stories/deptofculture',
    'https://www.blackownedbrooklyn.com/stories/good-wine',
    'https://www.blackownedbrooklyn.com/stories/brooklynsweetspot',
    'https://www.blackownedbrooklyn.com/stories/thenarativ',
    'https://www.blackownedbrooklyn.com/stories/kelewele',
    'https://www.blackownedbrooklyn.com/stories/bierwax',
    'https://www.blackownedbrooklyn.com/stories/zanmi',
    'https://www.blackownedbrooklyn.com/stories/mothershuckers',
    'https://www.blackownedbrooklyn.com/stories/macshack',
    'https://www.blackownedbrooklyn.com/stories/lipscafe',    
    'https://www.blackownedbrooklyn.com/stories/lotusscoop',
    'https://www.blackownedbrooklyn.com/stories/paperboyloveprince',    
    'https://www.blackownedbrooklyn.com/stories/cheris',    
    'https://www.blackownedbrooklyn.com/stories/brooklynsuya',
    'https://www.blackownedbrooklyn.com/stories/bakeryonbergen',
    'https://www.blackownedbrooklyn.com/stories/likkle',
    'https://www.blackownedbrooklyn.com/stories/joloff',
    'https://www.blackownedbrooklyn.com/stories/therogersgarden',
    'https://www.blackownedbrooklyn.com/stories/badnboozy',
    'https://www.blackownedbrooklyn.com/stories/brooklyn-supported-agriculture',
    'https://www.blackownedbrooklyn.com/stories/cuts-and-slices',
    'https://www.blackownedbrooklyn.com/stories/milk-and-pull',
    'https://www.blackownedbrooklyn.com/stories/bednos-liquidassets',
    'https://www.blackownedbrooklyn.com/stories/buy-better-foods',    
    'https://www.blackownedbrooklyn.com/stories/shaquanda-will-feed-you',    
    'https://www.blackownedbrooklyn.com/stories/ras-plant-based',
    'https://www.blackownedbrooklyn.com/stories/brown-butter',
    'https://www.blackownedbrooklyn.com/stories/cafe-on-ralph',
    'https://www.blackownedbrooklyn.com/stories/the-bergen',
    'https://www.blackownedbrooklyn.com/stories/black-nile',
    'https://www.blackownedbrooklyn.com/stories/bk9',
    'https://www.blackownedbrooklyn.com/stories/nurish',
    'https://www.blackownedbrooklyn.com/stories/italkitchen',
    'https://www.blackownedbrooklyn.com/stories/happy-cork',
    'https://www.blackownedbrooklyn.com/stories/zaca-cafe',
    'https://www.blackownedbrooklyn.com/stories/bcakeny',
    'https://www.blackownedbrooklyn.com/stories/daleview-biscuits-and-beer',
    'https://www.blackownedbrooklyn.com/stories/buntons-world-famous',
    'https://www.blackownedbrooklyn.com/stories/branch-patty',
    'https://www.blackownedbrooklyn.com/stories/bed-vyne-wine-spirits',
    'https://www.blackownedbrooklyn.com/stories/biyou',
    'https://www.blackownedbrooklyn.com/stories/rain-eatery-juice-bar',
    'https://www.blackownedbrooklyn.com/stories/brooklyn-tea',
    'https://www.blackownedbrooklyn.com/stories/akwaaba-mansion',
    'https://www.blackownedbrooklyn.com/stories/lakou-cafe',
    'https://www.blackownedbrooklyn.com/stories/bushwick-grind',
    'https://www.blackownedbrooklyn.com/stories/sofia-and-grace-cookie-company',
    'https://www.blackownedbrooklyn.com/stories/baby-jane',
    'https://www.blackownedbrooklyn.com/stories/bati-ethiopian-kitchen',
    'https://www.blackownedbrooklyn.com/stories/cheryls-global-soul',
    'https://www.blackownedbrooklyn.com/stories/the-juicy-box',
    'https://www.blackownedbrooklyn.com/stories/island-pops',
    'https://www.blackownedbrooklyn.com/stories/zurilee-pizza-bar',
    'https://www.blackownedbrooklyn.com/stories/basquiats-bottle',
    'https://www.blackownedbrooklyn.com/stories/creme-cocoa-creamery',
    'https://www.blackownedbrooklyn.com/stories/wine-o',
    'https://www.blackownedbrooklyn.com/stories/peppas-jerk-chicken',    
    'https://www.blackownedbrooklyn.com/stories/greedi-vegan',    
    'https://www.blackownedbrooklyn.com/stories/bottoms-up-wine-spirits',    
    'https://www.blackownedbrooklyn.com/stories/brooklyn-blend',
    'https://www.blackownedbrooklyn.com/stories/ode-to-babel',
    'https://www.blackownedbrooklyn.com/stories/abus-homestyle-bakery',
    'https://www.blackownedbrooklyn.com/stories/el-jeffe',
    'https://www.blackownedbrooklyn.com/stories/sol-sips',
    'https://www.blackownedbrooklyn.com/stories/grandchamps',
    'https://www.blackownedbrooklyn.com/stories/brooklyn-braised',
    'https://www.blackownedbrooklyn.com/stories/tip-top-bar-grill',
    'https://www.blackownedbrooklyn.com/stories/daddy-greens',
    'https://www.blackownedbrooklyn.com/stories/the-crabby-shack',
    'https://www.blackownedbrooklyn.com/stories/buka',
    'https://www.blackownedbrooklyn.com/stories/cafe-con-libros',
    'https://www.blackownedbrooklyn.com/stories/breukelen-coffee-house',
    'https://www.blackownedbrooklyn.com/stories/2015/11/23/mallorca-a-backdoor-paradise-x8hyj'
]
len(urls)
# newlist = urls
# Out:
# 73

# %%
#loop through the urls and send get request to the url
LOOP_COUNT = 0
NOT_FOUND_ARRAY = []

def Scrape(urls): 
    NA_COUNT = 0
    NO_ADDRESS_COUNT = 0
    NOT_FOUND = 0
    COUNT = 0
    while(len(urls)):
        index = 0
        url = urls[index]
    #     for url in urls:
#         url = urls[i]
        response = requests.get(url)
        del urls[0]
#         urls.pop(i)
        soup = BeautifulSoup(response.text, "html.parser")
        business_soupDiv = soup.find("div", {"class":"blog-item-title"})
    #   business_soupDiv = soup.select_one("div.blog-item-title")
        business_soupDiv = soup.select_one("article.entry--item")
        COUNT = COUNT + 1
        if (business_soupDiv):  
            ## GRAB BUSINESS NAME
    #       business_soup = business_soupDiv.find('h2', {"itemprop":"headline"})
            business_soup = business_soupDiv.select_one("h2.p-name")
            if (business_soup.text):
                business_text = business_soup.contents[1]
            else:
                business.text = "N/A"
                NA_COUNT = NA_COUNT + 1

            ## GRAB ADDRESS
            address_soup = business_soupDiv.select_one("div.sqs-block-content p em")
            address_text = address_soup.text if address_soup else "N/A"

            ## GRAB WEBSITE
            website_soup = business_soupDiv.select_one("div.sqs-block-content p em + a:last-of-type")
            website_soup2 = business_soupDiv.select_one("div.sqs-block-content p strong + a")
    #       website_soup3 = business_soupDiv.select_one("div.sqs-block-content p a")
            website_link = website_soup.get("href") if website_soup else "N/A"
            website_link = website_soup2.get("href") if website_soup2 else website_link
    #       website_link = website_soup3.get("href") if website_soup3 else website_link
        else:
            NOT_FOUND = NOT_FOUND + 1
            NOT_FOUND_ARRAY.append(url)
            continue


        
    #   business_text = business_soup.text if business_soup else "N/A" NA_COUNT = NA_COUNT + 1
        #address = soup.find('p', class_="", style = "white-space:pre-wrap;").find('em').get_text()
        #website_tag = soup.find('a', {'id': 'yui_3_17_2_1_1678698112318_524'})
        #website = website_tag.get('href')

        print('Business_Name:', business_text)
        print("Address: ", address_text)
        print("Website: ", website_link)
        #print('Address:', address)
        #print('Website:', website)
        print('Category:', "Food and drinks")
        print("NA_COUNT: ", NA_COUNT)
        print("COUNT: ", COUNT)
        print("NOT FOUND: ", NOT_FOUND)
        print("url: ", url)
        print("=============================")
Scrape(urls)
while(len(NOT_FOUND_ARRAY) and LOOP_COUNT <= 10):
    Scrape(NOT_FOUND_ARRAY)
    LOOP_COUNT = LOOP_COUNT + 1
print("=================================jl===================================")
print("NOT_FOUND_ARRAY: ", NOT_FOUND_ARRAY)
len(NOT_FOUND_ARRAY)
# urls = newlist
# Out:
# Business_Name: Dept of Culture
# Address:  327 Nostrand Ave., Brooklyn,
# Website:  https://deptofculturebk.com
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  1
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/deptofculture
# =============================
# Business_Name: Good Wine
# Address:  327 5th Ave, Brooklyn, 718-499-2392,
# Website:  https://goodwine.nyc
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  2
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/good-wine
# =============================
# Business_Name: Brooklyn Sweet Spot
# Address:
# Website:  https://www.thebrooklynsweetspot.com
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  3
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/brooklynsweetspot
# =============================
# Business_Name: The Narativ House x Brooklyn Kettle
# Address:  385 Tompkins Ave., 718-676-5154,
# Website:  https://www.brooklynkettle.com
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  4
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/thenarativ
# =============================
# Business_Name: Kelewele
# Address:  Dekalb Market Hall, 445 Albee Square W,, 929-322-3480,
# Website:  https://www.kelewelenyc.com
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  5
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/kelewele
# =============================
# Business_Name: BierWax
# Address:   347-533-8449,
# Website:  https://www.bierwaxnyc.com
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  6
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/bierwax
# =============================
# Business_Name: Zanmi
# Address:  1206 Nostrand Ave., 718-676-1047,
# Website:  https://www.zanminyc.com
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  7
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/zanmi
# =============================
# Business_Name: The Real Mother Shuckers
# Address:  am
# Website:  N/A
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  8
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/mothershuckers
# =============================
# Business_Name: Mac Shack
# Address:  320 Malcolm X Blvd., 718-210-9603,
# Website:  https://www.macshackny.com
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  9
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/macshack
# =============================
# Business_Name: Lips Cafe
# Address:  1412 Nostrand Ave, Brooklyn, 347-240-4439,
# Website:  N/A
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  10
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/lipscafe
# =============================
# Business_Name: Lotus Scoop
# Address:  *
# Website:  http://lotusscoop.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  11
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/lotusscoop
# =============================
# Business_Name: Paperboy Love Prince
# Address:  1254 Myrtle Avenue., Brooklyn,
# Website:  https://linktr.ee/PaperboyPrince
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  12
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/paperboyloveprince
# =============================
# Business_Name: Cheri's Bed-Stuy
# Address:  216 Malcolm X Blvd, 718-576-6655,
# Website:  https://www.instagram.com/cherisbedstuy/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  13
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/cheris
# =============================
# Business_Name: Brooklyn Suya
# Address:  717 Franklin Ave, Brooklyn
# Website:  https://www.brooklynsuya.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  14
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/brooklynsuya
# =============================
# Business_Name: The Bakery on Bergen
# Address:  740 Bergen St
# Website:  https://www.bakeryonbergen.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  15
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/bakeryonbergen
# =============================
# Business_Name: Likkle Jamaican Dumpling House
# Address:  you
# Website:  https://likkle.nyc/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  16
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/likkle
# =============================
# Business_Name: Joloff
# Address:  1168 Bedford Ave, Brooklyn, 718-230-0523,
# Website:  https://www.joloffjoloff.com
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  17
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/joloff
# =============================
# Business_Name: The Rogers Garden
# Address:  Tiki)
# Website:  https://www.therogersgarden.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  18
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/therogersgarden
# =============================
# Business_Name: Bad & Boozy
# Address:  and
# Website:  N/A
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  19
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/badnboozy
# =============================
# Business_Name: Brooklyn Supported Agriculture
# Address:  ﻿
# Website:  N/A
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  20
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/brooklyn-supported-agriculture
# =============================
# Business_Name: Cuts & Slices
# Address:  wants
# Website:  https://www.instagram.com/cutsandslicesnyc/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  21
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/cuts-and-slices
# =============================
# Business_Name: Milk & Pull
# Address:  too
# Website:  https://www.milkandpull.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  22
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/milk-and-pull
# =============================
# Business_Name: Bedford Nostrand Wine + Liquid Assets
# Address:  I’m
# Website:  https://bednos.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  23
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/bednos-liquidassets
# =============================
# Business_Name: Buy Better Foods
# Address:  372 Kosciuszko St, Brooklyn, 347-365-9550,
# Website:  https://www.buybetterfoods.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  24
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/buy-better-foods
# =============================
# Business_Name: Ras Plant Based
# Address:  739 Franklin Ave, Brooklyn, 718-622-6220,
# Website:  https://www.rasplantbased.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  26
# NOT FOUND:  1
# url:  https://www.blackownedbrooklyn.com/stories/ras-plant-based
# =============================
# Business_Name: Brown Butter Craft Bar & Kitchen
# Address:  perfect
# Website:  https://brownbutternyc.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  27
# NOT FOUND:  1
# url:  https://www.blackownedbrooklyn.com/stories/brown-butter
# =============================
# Business_Name: The Bergen
# Address:  1299 Bergen Street, 347-240-7046,
# Website:  https://www.thebergenbk.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  29
# NOT FOUND:  2
# url:  https://www.blackownedbrooklyn.com/stories/the-bergen
# =============================
# Business_Name: Black Nile
# Address:  592 Nostrand Ave, Brooklyn, 347-879-8911,
# Website:  https://blacknilerestaurant.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  30
# NOT FOUND:  2
# url:  https://www.blackownedbrooklyn.com/stories/black-nile
# =============================
# Business_Name: BK9
# Address:  62 5th Ave, Brooklyn, 718-789-2176,
# Website:  https://www.bk9.nyc/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  31
# NOT FOUND:  2
# url:  https://www.blackownedbrooklyn.com/stories/bk9
# =============================
# Business_Name: Nûrish
# Address:  637 Washington Ave, Brooklyn, 718-484-1122,
# Website:  https://www.nurishbk.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  32
# NOT FOUND:  2
# url:  https://www.blackownedbrooklyn.com/stories/nurish
# =============================
# Business_Name: Happy Cork
# Address:  welcome
# Website:  https://happy-cork.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  34
# NOT FOUND:  3
# url:  https://www.blackownedbrooklyn.com/stories/happy-cork
# =============================
# Business_Name: Zaca Cafe
# Address:  426  Marcus Garvey Blvd., 718- 443-2500,
# Website:  https://www.zacacafe.com
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  35
# NOT FOUND:  3
# url:  https://www.blackownedbrooklyn.com/stories/zaca-cafe
# =============================
# Business_Name: BCakeNY
# Address:  702 Washington Ave, Brooklyn, 347-787-7199,
# Website:  https://www.bcakeny.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  36
# NOT FOUND:  3
# url:  https://www.blackownedbrooklyn.com/stories/bcakeny
# =============================
# Business_Name: Daleview Biscuits and Beer
# Address:  1170 Nostrand Avenue, 347-240-5110,
# Website:  https://www.biscuitsandbeer.nyc
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  37
# NOT FOUND:  3
# url:  https://www.blackownedbrooklyn.com/stories/daleview-biscuits-and-beer
# =============================
# Business_Name: Bunton's World Famous
# Address:  N/A
# Website:  N/A
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  38
# NOT FOUND:  3
# url:  https://www.blackownedbrooklyn.com/stories/buntons-world-famous
# =============================
# Business_Name: Branch Patty
# Address:  www.branchpatty.com
# Website:  N/A
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  39
# NOT FOUND:  3
# url:  https://www.blackownedbrooklyn.com/stories/branch-patty
# =============================
# Business_Name: Bed-Vyne Wine & Spirits
# Address:  N/A
# Website:  N/A
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  40
# NOT FOUND:  3
# url:  https://www.blackownedbrooklyn.com/stories/bed-vyne-wine-spirits
# =============================
# Business_Name: Biyou
# Address:  joie de vivre
# Website:  https://biyoubk.com
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  41
# NOT FOUND:  3
# url:  https://www.blackownedbrooklyn.com/stories/biyou
# =============================
# Business_Name: Rain Eatery & Juice Bar
# Address:  1166 Nostrand Avenue, 718-484-1443,
# Website:  https://www.instagram.com/raineatery/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  42
# NOT FOUND:  3
# url:  https://www.blackownedbrooklyn.com/stories/rain-eatery-juice-bar
# =============================
# Business_Name: Brooklyn Tea
# Address:  extraordinary
# Website:  N/A
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  43
# NOT FOUND:  3
# url:  https://www.blackownedbrooklyn.com/stories/brooklyn-tea
# =============================
# Business_Name: Bushwick Grind
# Address:  63 Whipple Street, 929-337-6007,
# Website:  http://bushwickgrind.com
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  46
# NOT FOUND:  5
# url:  https://www.blackownedbrooklyn.com/stories/bushwick-grind
# =============================
# Business_Name: Sofia and Grace Cookie Company
# Address:  163 Ralph Avenue, 718-450-8034,
# Website:  https://www.instagram.com/sgcookiesco/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  47
# NOT FOUND:  5
# url:  https://www.blackownedbrooklyn.com/stories/sofia-and-grace-cookie-company
# =============================
# Business_Name: Baby Jane
# Address:  899 Fulton Street, 646-469-3333,
# Website:  https://www.instagram.com/babyjanebk/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  48
# NOT FOUND:  5
# url:  https://www.blackownedbrooklyn.com/stories/baby-jane
# =============================
# Business_Name: Bati Ethiopian Kitchen
# Address:  her
# Website:  https://batikitchen.com
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  49
# NOT FOUND:  5
# url:  https://www.blackownedbrooklyn.com/stories/bati-ethiopian-kitchen
# =============================
# Business_Name: Cheryl's Global Soul
# Address:  Melting Pot
# Website:  https://cherylsglobalsoul.com
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  50
# NOT FOUND:  5
# url:  https://www.blackownedbrooklyn.com/stories/cheryls-global-soul
# =============================
# Business_Name: The Juicy Box
# Address:  2281 Nostrand Avenue, 917-933-4088,
# Website:  https://www.instagram.com/thejuicyboxbar/?hl=en
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  51
# NOT FOUND:  5
# url:  https://www.blackownedbrooklyn.com/stories/the-juicy-box
# =============================
# Business_Name: Island Pops
# Address:  did
# Website:  http://islandpops.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  52
# NOT FOUND:  5
# url:  https://www.blackownedbrooklyn.com/stories/island-pops
# =============================
# Business_Name: Basquiat’s Bottle
# Address:  1198 Fulton Street, 347-533-8288,
# Website:  https://www.instagram.com/basquiatsbottle/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  54
# NOT FOUND:  6
# url:  https://www.blackownedbrooklyn.com/stories/basquiats-bottle
# =============================
# Business_Name: Wine-O
# Address:  602 Marcy Avenue, 718-222-9463,
# Website:  https://www.instagram.com/brooklynwineobedstuy/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  56
# NOT FOUND:  7
# url:  https://www.blackownedbrooklyn.com/stories/wine-o
# =============================
# Business_Name: Peppa's Jerk Chicken
# Address:  738 Flatbush Avenue, 917-673-6225,
# Website:  https://www.instagram.com/peppasjerkchicken0/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  57
# NOT FOUND:  7
# url:  https://www.blackownedbrooklyn.com/stories/peppas-jerk-chicken
# =============================
# Business_Name: Bottoms Up Wine
# Address:  731 Franklin Avenue, 347-425-7474,
# Website:  https://bottomsupwinenspirits.com
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  59
# NOT FOUND:  8
# url:  https://www.blackownedbrooklyn.com/stories/bottoms-up-wine-spirits
# =============================
# Business_Name: Brooklyn Blend
# Address:  194 Tompkins Avenue, 718-484-2247,
# Website:  http://bklynblend.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  60
# NOT FOUND:  8
# url:  https://www.blackownedbrooklyn.com/stories/brooklyn-blend
# =============================
# Business_Name: Ode To Babel
# Address:  772 Dean Street, 718-484-3847,
# Website:  http://odetobabel.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  61
# NOT FOUND:  8
# url:  https://www.blackownedbrooklyn.com/stories/ode-to-babel
# =============================
# Business_Name: Abu's Homestyle Bakery
# Address:  absolutely
# Website:  https://abusbakery.com
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  62
# NOT FOUND:  8
# url:  https://www.blackownedbrooklyn.com/stories/abus-homestyle-bakery
# =============================
# Business_Name: El Jeffe
# Address:  exactly
# Website:  https://www.instagram.com/eljeffenyc/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  63
# NOT FOUND:  8
# url:  https://www.blackownedbrooklyn.com/stories/el-jeffe
# =============================
# Business_Name: Sol Sips
# Address:  203 Wilson Avenue, 718-683-0482,
# Website:  https://www.instagram.com/solsipsnyc/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  64
# NOT FOUND:  8
# url:  https://www.blackownedbrooklyn.com/stories/sol-sips
# =============================
# Business_Name: Grandchamps
# Address:  197 Patchen Avenue, 718-484-4880,
# Website:  http://www.grandchamps.nyc/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  65
# NOT FOUND:  8
# url:  https://www.blackownedbrooklyn.com/stories/grandchamps
# =============================
# Business_Name: Brooklyn Braised
# Address:   brooklynbraised.com
# Website:  N/A
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  66
# NOT FOUND:  8
# url:  https://www.blackownedbrooklyn.com/stories/brooklyn-braised
# =============================
# Business_Name: Daddy Greens
# Address:  UPDATE: This business’ location has changed.
# Website:  https://www.daddygreens.nyc/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  68
# NOT FOUND:  9
# url:  https://www.blackownedbrooklyn.com/stories/daddy-greens
# =============================
# Business_Name: The Crabby Shack
# Address:  613 Franklin Avenue, 718-484-1507,
# Website:  http://thecrabbyshack.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  69
# NOT FOUND:  9
# url:  https://www.blackownedbrooklyn.com/stories/the-crabby-shack
# =============================
# Business_Name: Buka
# Address:   is
# Website:  http://www.bukanewyork.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  70
# NOT FOUND:  9
# url:  https://www.blackownedbrooklyn.com/stories/buka
# =============================
# Business_Name: Cafe Con Libros
# Address:  Freshwater
# Website:  https://www.cafeconlibrosbk.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  71
# NOT FOUND:  9
# url:  https://www.blackownedbrooklyn.com/stories/cafe-con-libros
# =============================
# Business_Name: Jemz
# Address:  everything
# Website:  N/A
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  73
# NOT FOUND:  10
# url:  https://www.blackownedbrooklyn.com/stories/2015/11/23/mallorca-a-backdoor-paradise-x8hyj
# =============================
# Business_Name: Shaquanda's Hot Pepper Sauce
# Address:  N/A
# Website:  N/A
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  1
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/shaquanda-will-feed-you
# =============================
# Business_Name: Cafe On Ralph (Closed)
# Address:  UPDATE: This business has closed, but you can still enjoy its menu at sister restaurant Brooklyn Beso (370 Lewis Avenue).
# Website:  http://cafeonralphavenue.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  2
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/cafe-on-ralph
# =============================
# Business_Name: Ital Kitchen
# Address:  started
# Website:  https://www.italkitchenbk.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  3
# NOT FOUND:  0
# url:  https://www.blackownedbrooklyn.com/stories/italkitchen
# =============================
# Business_Name: Lakou Cafe
# Address:  really
# Website:  https://lakoucafe.com
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  5
# NOT FOUND:  1
# url:  https://www.blackownedbrooklyn.com/stories/lakou-cafe
# =============================
# Business_Name: Zurilee Pizza Bar
# Address:  know
# Website:  https://zurileepizza.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  6
# NOT FOUND:  1
# url:  https://www.blackownedbrooklyn.com/stories/zurilee-pizza-bar
# =============================
# Business_Name: Crème & Cocoa Creamery
# Address:  1067 Nostrand Avenue, 718-245-6286,
# Website:  http://cremeandcocoa.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  7
# NOT FOUND:  1
# url:  https://www.blackownedbrooklyn.com/stories/creme-cocoa-creamery
# =============================
# Business_Name: Greedi Vegan
# Address:  did
# Website:  https://greedivegan.com
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  8
# NOT FOUND:  1
# url:  https://www.blackownedbrooklyn.com/stories/greedi-vegan
# =============================
# Business_Name: Tip-Top Bar & Grill
# Address:  432 Franklin Ave., 718-857-9744,
# Website:  https://www.facebook.com/tiptopbarandgrill/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  9
# NOT FOUND:  1
# url:  https://www.blackownedbrooklyn.com/stories/tip-top-bar-grill
# =============================
# Business_Name: Akwaaba Mansion
# Address:  so
# Website:  https://akwaaba.com
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  11
# NOT FOUND:  2
# url:  https://www.blackownedbrooklyn.com/stories/akwaaba-mansion
# =============================
# Business_Name: Breukelen Coffee House
# Address:  764 Franklin Avenue, 718-789-7070,
# Website:  http://owww.breukelencoffeehouse.com/
# Category: Food and drinks
# NA_COUNT:  0
# COUNT:  12
# NOT FOUND:  2
# url:  https://www.blackownedbrooklyn.com/stories/breukelen-coffee-house
# =============================
# =================================jl===================================
# NOT_FOUND_ARRAY:  []
# 0
